# %%
import numpy as np

# %%
np.array([1, 2, 3, 4, 5, 6])
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr = np.ndarray((2, 3), dtype=int)
print(arr)
# Out:
# [[            0          2096             0]
#  [1976562660144             0         65793]]
