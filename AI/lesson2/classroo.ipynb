# %% [markdown]
# Trik qolgan ayollarning sonini topish

# %%
import pandas as pd


df = pd.read_csv("Titanic Dataset.csv")


count = 0

df = df[(df['sex']=='female') & (df['survived']==1)]

df['survived'].count()
# Out:
# np.int64(339)

# %% [markdown]
# 339 ta ekan

# %% [markdown]
# Trik qolgan erkaklarning sonini topish

# %%
import pandas as pd


df = pd.read_csv("Titanic Dataset.csv")


count = 0

df = df[(df['sex']=='male') & (df['survived']==1)]

df['survived'].count()
# Out:
# np.int64(161)

# %% [markdown]
# 161 ta ekan

# %% [markdown]
# #############

# %%
df = pd.read_csv("Titanic Dataset.csv")
df = df[(df['pclass']==1) & (df['survived']==1)]
df["survived"].count()
# Out:
# np.int64(200)

# %%
import pandas as pd

s = pd.Series([10, 20, 30])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
